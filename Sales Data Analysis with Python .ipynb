# %% [markdown]
# <a href="https://colab.research.google.com/github/AbenezerYBekele/data-analyst/blob/main/Sales%20Data%20Analysis%20with%20Python%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retail sales dataset analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df = pd.read_csv('SalesData.csv')
df.head()
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#      Sales            City  Hour
# 0  1700.00   New York City     0
# 1   600.00   New York City     7
# 2    11.95   New York City    18
# 3   149.99   San Francisco    15
# 4    11.95         Atlanta    12
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['Order ID'].plot(kind='hist', bins=20, title='Order ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['Price Each'].plot(kind='hist', bins=20, title='Price Each')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_9.groupby('Product').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_10.groupby('Order Date').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_11.groupby('Purchase Address').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('City').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13.plot(kind='scatter', x='index', y='Unnamed: 0', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14.plot(kind='scatter', x='Unnamed: 0', y='Order ID', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15.plot(kind='scatter', x='Order ID', y='Price Each', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='Price Each', y='Sales', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Price Each']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_17.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Product')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Product', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Price Each')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Price Each']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_18.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Order Date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Order Date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Price Each')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Price Each']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_19.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Purchase Address')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Purchase Address', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Price Each')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Price Each']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_20.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('City')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='City', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Price Each')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['Order ID'].plot(kind='line', figsize=(8, 4), title='Order ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['Price Each'].plot(kind='line', figsize=(8, 4), title='Price Each')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Order Date'].value_counts()
#     for x_label, grp in _df_25.groupby('Product')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Product')
# _ = plt.ylabel('Order Date')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Purchase Address'].value_counts()
#     for x_label, grp in _df_26.groupby('Order Date')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Order Date')
# _ = plt.ylabel('Purchase Address')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['City'].value_counts()
#     for x_label, grp in _df_27.groupby('Purchase Address')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Purchase Address')
# _ = plt.ylabel('City')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_28['Product'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_28, x='index', y='Product', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_29['Order Date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_29, x='index', y='Order Date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_30['Purchase Address'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_30, x='index', y='Purchase Address', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_31['City'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_31, x='index', y='City', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
#  Data overview , summary statistics and checking for missing values

# %%
df.info()

df.describe()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        185950 non-null  int64
#  1   Order ID          185950 non-null  int64
#  2   Product           185950 non-null  object
#  3   Quantity Ordered  185950 non-null  int64
#  4   Price Each        185950 non-null  float64
#  5   Order Date        185950 non-null  datetime64[ns]
#  6   Purchase Address  185950 non-null  object
#  7   Month             185950 non-null  object
#  8   Sales             185950 non-null  float64
#  9   City              185950 non-null  object
#  10  Hour              185950 non-null  int64
#  11  Cost Each         185950 non-null  float64
#  12  Total Cost        185950 non-null  float64
#  13  Profit            185950 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(4)
# memory usage: 19.9+ MB
# Unnamed: 0          0
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# Sales               0
# City                0
# Hour                0
# Cost Each           0
# Total Cost          0
# Profit              0
# dtype: int64

# %% [markdown]
# Monthly Revenue Trend

# %%
df['Month'] = df['Month'].astype(str)

monthly_sales = df.groupby('Month')['Sales'].sum().sort_index()

plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='bar', color='skyblue')
plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# Top 10 spending addresses customer insights

# %%
top_customers = df.groupby('Purchase Address')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
top_customers.plot(kind='barh', color='teal')
plt.title('Top 10 Customers by Revenue (based on Purchase Address)')
plt.xlabel('Revenue')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# Total revenue by City

# %%
city_sales = df.groupby('City')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
city_sales.plot(kind='bar', color='orange')
plt.title('Total Revenue by City')
plt.xlabel('City')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Correlation matrix

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Product-Level Sales Trends

# %%
product_sales = df.groupby('Product')['Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
product_sales.plot(kind='bar', color='mediumseagreen')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.xticks(rotation=75)
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# Profit Margin Analysis

# %%
df['Cost Each'] = df['Price Each'] * 0.3
df['Total Cost'] = df['Cost Each'] * df['Quantity Ordered']
df['Profit'] = df['Sales'] - df['Total Cost']

product_profit = df.groupby('Product')['Profit'].sum().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
product_profit.plot(kind='bar', color='coral')
plt.title('Total Profit by Product')
plt.xlabel('Product')
plt.ylabel('Profit')
plt.xticks(rotation=75)
plt.tight_layout()
plt.grid(True)
plt.show()

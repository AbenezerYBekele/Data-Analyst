# %% [markdown]
# # 📊 Exploratory Data Analysis of Stock Market Trends: A Comparative Study of Tesla and GameStop
#
# ## Introduction
# The stock market is driven by a complex interplay of company performance, investor sentiment, and market events. While some companies exhibit steady growth tied to their financial fundamentals, others can experience dramatic volatility fueled by external narratives. This project delves into these divergent paths by analyzing two of the most talked-about stocks of the last decade: Tesla (TSLA) and GameStop (GME).
# <br>
# This project demonstrates an end-to-end data analysis workflow, performing an exploratory data analysis (EDA) on historical stock price and revenue data from 2010 to the end of 2020. Utilizing Python and key libraries such as yfinance for data acquisition, pandas for data manipulation, and matplotlib/plotly for visualization, this analysis compares the long-term growth trajectory of Tesla against the event-driven volatility of GameStop.
# <br>
# The goal is to showcase the ability to work with raw financial data, transform it into a clean and usable format, and extract meaningful business insights through clear and effective visualizations. By juxtaposing these two distinct case studies, this analysis highlights the importance of looking beyond the ticker price to understand the underlying drivers of market valuation.

# %% [markdown]
# ## 🔍 Data Overview
# Let's start by importing the dataset and understanding its structure.

# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# !pip install --upgrade plotly
# Out:
# ...
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# ...

# %% [markdown]
# ## 🧹 Data Cleaning & Preparation
# Before analysis, we need to ensure the data is clean and well-structured.

# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# !pip install --upgrade plotly
# Out:
# ...
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# ...

# %%
# !pip install yfinance
import yfinance as yf
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Out:
# ...
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.io as pio
pio.renderers.default = "iframe"

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
def make_graph(stock_data, revenue_data, stock):
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
    stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']
    fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data_specific.Date, infer_datetime_format=True), y=stock_data_specific.Close.astype("float"), name="Share Price"), row=1, col=1)
    fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data_specific.Date, infer_datetime_format=True), y=revenue_data_specific.Revenue.astype("float"), name="Revenue"), row=2, col=1)
    fig.update_xaxes(title_text="Date", row=1, col=1)
    fig.update_xaxes(title_text="Date", row=2, col=1)
    fig.update_yaxes(title_text="Price ($US)", row=1, col=1)
    fig.update_yaxes(title_text="Revenue ($US Millions)", row=2, col=1)
    fig.update_layout(showlegend=False,
    height=900,
    title=stock,
    xaxis_rangeslider_visible=True)
    fig.show()
    from IPython.display import display, HTML
    fig_html = fig.to_html()
    display(HTML(fig_html))

# %%
tesla_data = yf.download('TSLA', start='2010-01-01', end='2020-12-31')
tesla_data.reset_index(inplace=True)
print(tesla_data.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
print(tesla_revenue.tail())
# Out:
#          Date  Revenue
# 48 2010-09-30       31
# 49 2010-06-30       28
# 50 2010-03-31       21
# 51 2009-09-30       46
# 52 2009-06-30       27

# %%
gme_data = yf.download('GME', start='2010-01-01', end='2020-12-31')
gme_data.reset_index(inplace=True)
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863059  3.703150  3.714933   26702800
# 1      2010-01-05  3.959005  3.996036  3.854643  3.856326   21269600
# 2      2010-01-06  4.044849  4.056632  3.908506  3.948904   21471200
# 3      2010-01-07  3.443930  3.563441  3.268872  3.368184  164761200
# 4      2010-01-08  3.415315  3.573540  3.405215  3.474228   47872400

# %%
print(tesla_revenue.tail())
# Out:
#          Date  Revenue
# 48 2010-09-30       31
# 49 2010-06-30       28
# 50 2010-03-31       21
# 51 2009-09-30       46
# 52 2009-06-30       27

# %%
for row in revenue_table.find_all("tr"):
    col = row.find_all("td")
    if len(col) == 2:
        date = col[0].text.strip()
        revenue = col[1].text.strip().replace(",", "").replace("$", "")
        tesla_revenue.loc[len(tesla_revenue)] = [date, revenue]

# %%
print(tesla_revenue.tail())
# Out:
#          Date Revenue
# 48 2009-06-30      27
# 49 2010-06-30      28
# 50 2010-03-31      21
# 51 2009-09-30      46
# 52 2009-06-30      27

# %%
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(r',|\$', "")

# %% [markdown]
# ## 📈 Exploratory Data Analysis (EDA)
# In this section, I explore trends, distributions, and relationships in the dataset.

# %%
tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]

# %%
gme_data = yf.download('GME', start='2010-01-01', end='2024-01-01')
gme_data.reset_index(inplace=True)
print(gme_data.head())
gme_revenue = pd.DataFrame(columns=["Date", "Revenue"])
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863059  3.703150  3.714933   26702800
# 1      2010-01-05  3.959006  3.996037  3.854644  3.856328   21269600
# 2      2010-01-06  4.044850  4.056633  3.908506  3.948904   21471200
# 3      2010-01-07  3.443930  3.563441  3.268873  3.368184  164761200
# 4      2010-01-08  3.415314  3.573540  3.405215  3.474228   47872400

# %%
print(  gme_data.head())
# Out:
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863059  3.703150  3.714933   26702800
# 1      2010-01-05  3.959006  3.996037  3.854644  3.856328   21269600
# 2      2010-01-06  4.044850  4.056633  3.908506  3.948904   21471200
# 3      2010-01-07  3.443930  3.563441  3.268873  3.368184  164761200
# 4      2010-01-08  3.415314  3.573540  3.405215  3.474228   47872400

# %%
make_graph(gme_data, 'GameStop Stock Price Over Time')

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(14, 6))
    plt.plot(data['Date'], data['Close'], label='Closing Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price (USD)')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")  # You can use "5y", "1y", etc., if you want less data
tesla_data.reset_index(inplace=True)

# %%
tesla_data['Date'] = pd.to_datetime(tesla_data['Date'])
tesla_data = tesla_data.sort_values('Date')

# %%
make_graph(tesla_data, 'Tesla Stock Price Over Time')

# %%
make_graph=yf.download('TSLA', start='2010-01-01', end='2020-12-31')
make_graph.reset_index(inplace=True)
print(make_graph.head())
tesla_revenue = pd.DataFrame(columns=["Date", "Revenue"])
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
rows = []
for row in table.find_all("tr"):
    cols = row.find_all("td")
    if len(cols) == 2:
        date = cols[0].text.strip()
        revenue = cols[1].text.strip()
        rows.append({"Date": date, "Revenue": revenue})

tesla_revenue = pd.DataFrame(rows)
tesla_revenue["Revenue"] = tesla_revenue["Revenue"].str.replace(r',|\$', "", regex=True)
tesla_revenue.dropna(inplace=True)
tesla_revenue = tesla_revenue[tesla_revenue["Revenue"] != ""]

# %%
gme = yf.Ticker("GME")
gme_data = gme.history(period="max")
gme_data.reset_index(inplace=True)
gme_data['Date'] = pd.to_datetime(gme_data['Date'])
gme_data = gme_data[gme_data['Date'] <= '2021-06-30']

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html5lib")

tables = soup.find_all("table")

for table in tables:
    if "GameStop Quarterly Revenue" in table.text:
        revenue_table = table
        break

rows = []
for row in revenue_table.find_all("tr"):
    cols = row.find_all("td")
    if len(cols) == 2:
        date = cols[0].text.strip()
        revenue = cols[1].text.strip().replace("$", "").replace(",", "")
        if revenue != "":
            rows.append({"Date": date, "Revenue": revenue})

gme_revenue = pd.DataFrame(rows)
gme_revenue["Date"] = pd.to_datetime(gme_revenue["Date"])
gme_revenue["Revenue"] = pd.to_numeric(gme_revenue["Revenue"])
gme_revenue = gme_revenue[gme_revenue['Date'] <= '2021-06-30']

# %%
def make_graph(stock_data, revenue_data, stock):
    fig, ax1 = plt.subplots(figsize=(14, 6))

    ax1.plot(stock_data['Date'], stock_data['Close'], 'b-', label='Stock Price')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Stock Price (USD)', color='b')
    ax1.tick_params('y', colors='b')
    ax1.set_title(f"{stock} Stock Price and Revenue")

    ax2 = ax1.twinx()
    ax2.plot(revenue_data['Date'], revenue_data['Revenue'], 'r-', label='Revenue')
    ax2.set_ylabel('Revenue (USD)', color='r')
    ax2.tick_params('y', colors='r')

    fig.tight_layout()
    plt.show()

# %%
make_graph(gme_data, gme_revenue, 'GameStop')

# %% [markdown]
# ## 💡 **Insights**
# This exploratory analysis of Tesla (TSLA) and GameStop (GME) stock data from 2010 through the end of 2020 reveals distinct growth narratives and performance trajectories.
#
# - **Contrasting Growth Stories:** The visualizations clearly illustrate two fundamentally different market stories. Tesla's stock price demonstrates a long-term, exponential growth trend, which appears to be correlated with its steadily increasing revenue. This suggests a growth narrative driven by strong business fundamentals and market confidence over the decade.
# - **Event-Driven Volatility:**  In contrast, GameStop's stock price remained relatively flat for most of the decade before experiencing a dramatic, short-term spike. This volatility does not show a similar correlation with its revenue, indicating that its valuation was likely driven by external market events, such as the widely publicized short squeeze, rather than internal financial performance.
# - **Revenue as a Key Indicator:** For Tesla, the relationship between rising revenue and increasing stock price is visually apparent. This underscores the principle that for growth-oriented companies, consistent revenue generation can be a strong indicator of long-term stock value appreciation.
# - **Market Sentiment vs. Financial Health:** The GameStop analysis highlights a key takeaway: market sentiment and external events can temporarily decouple a stock's price from its underlying financial health. While revenue is a critical metric, this case demonstrates that it is not the sole driver of stock valuation, especially in the short term.

# %% [markdown]
# ## **Conclusion & Next Steps**
#
#    This project successfully demonstrates a complete data analysis workflow, from data acquisition and cleaning to exploratory analysis and visualization. By leveraging Python libraries such as yfinance, pandas, and matplotlib, this analysis transformed raw stock and revenue data into a clear comparative narrative of Tesla's fundamental-driven growth and GameStop's event-driven volatility.
#  <br>
#     The key takeaway is the critical importance of looking beyond surface-level stock prices to understand the underlying drivers of value. The juxtaposition of these two companies serves as a compelling case study on how different factors—be it consistent revenue growth or speculative market events—can impact market performance.
